# %% [markdown]
# ## Word Embedding

# %% [markdown]
# In NLP, term used for represntation of words for text analysis,
# in the form of real-valued vector that encodes the meaning of the word such that
# the words that are closer in the vector space are expected to be similar in meaning.

# %%
Angry               Happy              Excited

[   ]              [   ]               [     ]


Count or Frequency              Deep Learning Trained Model
1. OHE                          1. Word2Vec  -> CBOW ( Continous Bag Of Words )
2. BOW                                       -> Skipgram
3. TF-IDF
