# %% [markdown]
# ## Text Preprocessing

# %% [markdown]
# ### 1. DataSet -> 2. Text Preprocessing - 1 -> 3. Text Preprocessing - 2 -> 4. Vectors -> 5. ML or DL Algo.

# %% [markdown]
# ## Text Preprocessing-1
#
# 1. Tokenization
# 2. Lowercase the words
# 3. Regular Expressions
#
# ## Text Preprocessing-2
#
# 1. Stemming
# 2. Lemmatization
# 3. Stop words
#
# ## Vectors
#
# 1. One Hot Encoded
# 2. Bag of Words (BOW)
# 3. TF-IDF
# 4. Word2Vec
# 5. AvgWord2Vec
