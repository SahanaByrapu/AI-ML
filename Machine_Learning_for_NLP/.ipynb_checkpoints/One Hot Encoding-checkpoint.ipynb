# %% [markdown]
# ## One Hot Encoding

# %% [markdown]
# Vocabulary { unique words }

# %% [markdown]
# The food is good bad Pizza Amazing

# %%
Advantages                                                           Disadvantages
1. Easy to Implement with %%python                                 1. Sparse matrix -> Overfitting
[ sklearn, oneHorEncoder,                                          2. ML Algorithm -> Fixed Size I/P
                                                                   3. No Semantic Meaning is getting captured
                                                                   4. Out of vocabulary
