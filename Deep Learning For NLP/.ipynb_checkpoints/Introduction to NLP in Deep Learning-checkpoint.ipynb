# %% [markdown]
# ## NLP In Deep Learning

# %%
Text Data  -> Vectors -> Numerical Representation

# %%
Part1

ANN -> Artificial Neural Network -> Classification
                                 -> Regression

Eg: House Price Prediction

Sequence of Data Doesn't matter

Backpropgation -> to adjust the weights as per the loss =[Yi -yi]

# %%
Part 2

CNN -> Convolutional Neural Network -> 
Data -> Images, Video Frames

Eg: Image Classiifcation, Object

# %%
Part 3

Data -> Sequential Data
                           Input                                 Output
1. Text Generation ->  [Sentence]This is a apple juice     

2. Chatbot Conversation -> Question & Answer


3. Language Translation ->   English  -> French


4. Auto Suggestion -> LinkedIn, Gmail -> Autosuggestion

5. Sales Data -> DateTime

# %% [markdown]
# ## Can we use ANN to solve this problem? -> {Sequential Data}

# %%
NLP In Deep Learning

# %%
1. Simple RNN -> LSTM / GRU RNN -> Bidirectional RNN -> Encoders-Decoders -> Self-Attention -> Transformers-> Gen-AI
